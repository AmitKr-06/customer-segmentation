# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import joblib

# %%
# Load PCA data
X_train_pca = np.load('../data/processed/X_train_pca.npy')
X_test_pca = np.load('../data/processed/X_test_pca.npy')

# %%
# Load BDSCAN labels (best model)
train_labels = np.load('../data/processed/train_labels_dbscan_final.npy')
test_labels = np.load('../data/processed/test_labels_dbscan_final.npy')

# %%
print(f"Train Shape: {X_train_pca.shape}, Train Labels: {train_labels.shape}" )
print(f"Test Shape: {X_test_pca.shape}, Test Labels: {test_labels.shape}")
# Out:
# Train Shape: (1792, 8), Train Labels: (1792,)
# Test Shape: (448, 8), Test Labels: (448,)

# %%
# Cluster Distribution

# Count clusters (ex)
